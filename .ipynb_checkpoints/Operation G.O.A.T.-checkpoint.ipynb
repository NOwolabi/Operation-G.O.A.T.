# %%
# %matplotlib notebook

from modsim import *
from math import *

# %%
print('Operation G.O.A.T.')
# Out:
# Operation G.O.A.T.

# %%
m = UNITS.meter
s = UNITS.second
n = UNITS.newtons
deg = UNITS.degrees
kg = UNITS.kilograms
#knot = 1.8520008892119 * miles * 60 * second


def force_g(m):
    q = (m) * (-9.8)
    force = q * newton
    return force
    
def torque(force, r, x):
    torque = force * (r * meter) * (sin(x) * degrees)
    return torque

def accel(mass_of_people):
    acceleration_of_agent = ((mass_of_people * kg) * (-9.8 * meter / (second ** 2))) / (mass_of_agent * kg)
    return acceleration_of_agent

def launch_angle(sin_theta):
    sign_theta = (torque_of_peoples)/(fg_of_agent*r)
    angle = arcsin(sign_theta)
    return angle

# %%
print('force needed to take out a guy on impact')
print('code the equations to model the position of the components over time')
print('code the sweep to show how many people it will take to knock over the guy on impact')
print('time delay before launch so that agent knocks guy out on impact')
# Out:
# force needed to take out a guy on impact
# code the equations to model the position of the components over time
# code the sweep to show how many people it will take to knock over the guy on impact
# time delay before launch so that agent knocks guy out on impact

# %%
condition = Condition(x = 0 * m, 
                      y = 1 * m,
                      g = 9.8 * m/s**2,
                      mass = 22e4 * kg,
                      rho = 1.2 * kg/m**3,
                      C_d = 0.3,
                      angle = 45 * deg,
                      velocity = 40 * m / s,
                      duration = 5.1 * s)

#not done with this cell

# %%
def distancedif (t):
    yachtv=3.08667
    x0=15
    y=10
    
    xdif=x0-yachtv*(t)
    P=Vector(xdif,y)
    dif=P.mag
    return dif

# %%
distancedif(5)
# Out:
# <Quantity(10.00938520701946, 'dimensionless')>

# %%
def targetmove(t):
    tseries=TimeSeries()
    for i in range (t):
        tseries[i]=distancedif(i)
    return tseries

# %%
x=targetmove(25)
x
# Out:
# 0     18.027756377319946 dimensionless
# 1     15.554016577363546 dimensionless
# 2     13.338287999424814 dimensionless
# 3     11.530285564551296 dimensionless
# 4     10.346018897257052 dimensionless
# 5      10.00938520701946 dimensionless
# 6     10.601440505912391 dimensionless
# 7     11.985339075558104 dimensionless
# 8     13.926996377166182 dimensionless
# 9     16.227420213974245 dimensionless
# 10    18.755057155071533 dimensionless
# 11     21.42965782174088 dimensionless
# 12    24.202548692267925 dimensionless
# 13    27.043512261244835 dimensionless
# 14    29.933172418312097 dimensionless
# 15    32.858684240281136 dimensionless
# 16     35.81126236756252 dimensionless
# 17     38.78472583494821 dimensionless
# 18     41.77461510539145 dimensionless
# 19     44.77763995224514 dimensionless
# 20    47.791324270833925 dimensionless
# 21    50.813771507386654 dimensionless
# 22    53.843505991229804 dimensionless
# 23    56.879363247386124 dimensionless
# ...

# %%
newfig()
plot(x)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def energy(nump):
    massp=75     #in kg = 165lbs
    h=10 #meters
    E=massp*nump*(9.8)*h
    return E

# %%
energy(10)
# Out:
# 73500.00000000001

# %%
def E2v(nump):
    E=energy(nump)
    massp=75 #kg
    v=sqrt((2*E)/massp)
    return v

# %%
E2v(10)
# Out:
# 44.271887242357316

# %%
def hofagent(nump):
    v_init=E2v(nump)
    angle=45 #degrees

# %%
def Fonimpact(xtraveledbyagent,v0,vf):
    KEo=.5*(massp*nump)*v0**2
    KEf=.5*(massp*nump)*vf**2
    change=KEf-KEo
    F=change/xtraveledbyagent
    return F

# %%
def position(nump, t):
    v=v_init(nump)
    dvdt=accman1(nump)
    ypos=dvdt*t**2+v*t
    return ypos

# %%
def forceoflaunch(nump):    
    finalvel=14    #m/s
    Ke=.5*nump*(finalvel**2)
    F=Ke
    return F
forceoflaunch(5)
# Out:
# 490.0

# %%
def v_init(nump):
    F=forceoflaunch(nump)
    mass=75
    vout=sqrt((2*F)/mass)      #something funny here
    return vout

# %%
def accman1(nump):
    F=forceoflaunch(nump)
    Vo=v_init(nump)
    angle=45 #deg
    ax=(F*cos(angle))/nump*75
    ay=(F*sin(angle))-(nump*75*9.8)-(1.14*(Vo**2))
    aa=(ax**2)+(ay**2)
    a=sqrt(aa)
    return a

# %%
system=System(t0=0, t_end=10)
def yposovertime(system):
    res=TimeSeries()
    for i in linrange(system.t0, system.t_end):
        res[i]=position(3, i)
    system.yresults=res
    return system.yresults
yposovertime(system)
system.yresults
# Out:
# 0          0.000000
# 1       4334.615077
# 2      17332.860308
# 3      38994.735694
# 4      69320.241233
# 5     108309.376927
# 6     155962.142775
# 7     212278.538777
# 8     277258.564934
# 9     350902.221244
# 10    433209.507709
# dtype: float64

# %%
newfig()
plot(system.yresults, label="Vertical Height over Time")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def xposition(x_v_init, t):
    xpos=x_v_init*t
    return xpos

# %%
def xposovertime(system):
    res=TimeSeries()
    for i in linrange(system.t0, system.t_end):
        res[i]=xposition(2, i)
    system.results=res
    return system.results
xposovertime(system)
system.results
# Out:
# 0      0.0
# 1      2.0
# 2      4.0
# 3      6.0
# 4      8.0
# 5     10.0
# 6     12.0
# 7     14.0
# 8     16.0
# 9     18.0
# 10    20.0
# dtype: float64

# %%
newfig()
plot(system.results, system.yresults, label="trajectory of agent over time")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def ppl(v_init2, t, acc):
    """Calculates vertical position of jumpers over time
    initial position is 10 meters"""
    ypos=-acc*t**2+v_init2*t + 10
    return ypos

# %%
def pplovertime(system):
    res=TimeSeries()
    for i in linrange(system.t0, system.t_end):
        res[i]=ppl(0, i, 9.8)
    system.results=res
    return system.results
pplovertime(system)
system.results
# Out:
# 0      10.0
# 1       0.2
# 2     -29.2
# 3     -78.2
# 4    -146.8
# 5    -235.0
# 6    -342.8
# 7    -470.2
# 8    -617.2
# 9    -783.8
# 10   -970.0
# dtype: float64

# %%
def finalxpos(t):
# Out:
#   File "<ipython-input-37-0aa36a302116>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def forceoflaunch(nump):    
    finalvel=14    #m/s
    Ke=.5*nump*(finalvel**2)
    F=Ke
    return F
forceoflaunch(5)
# Out:
# 490.0

# %%
def accman(nump):
    F=forceoflaunch(nump)
    Vo=v_init(nump)
    a=(F-1.14*(Vo**2)-(9.8*nump*75))/75     #something funny here
    return a
accman(3)
# Out:
# -25.599168

# %%
def v_init(nump):
    F=forceoflaunch(nump)
    mass=75
    vout=sqrt((2*F)/mass)      #something funny here
    return vout

# %%
def accman1(nump):
    F=forceoflaunch(nump)
    Vo=v_init(nump)
    angle=45 #deg
    ax=(F*cos(angle))/nump*75
    ay=(F*sin(angle))-(nump*75*9.8)-(1.14*(Vo**2))
    aa=(ax**2)+(ay**2)
    a=sqrt(aa)
    return a

# %%
def v_init1(nump):
    F=forceoflaunch(nump)
    mass=75
    vout=sqrt((2*F)/mass)      #something funny here
    return vout
