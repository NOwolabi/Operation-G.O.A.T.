# %%
# %matplotlib notebook

from modsim import *
from math import *

# %%
print('Operation G.O.A.T.')
# Out:
# Operation G.O.A.T.

# %%
m = UNITS.meter
s = UNITS.second
n = UNITS.newtons
deg = UNITS.degrees
kg = UNITS.kilograms
#knot = 1.8520008892119 * miles * 60 * second

# %%
condition = Condition(x = 0 * m, 
                      y = 1 * m,
                      g = 9.8 * m/s**2,
                      mass = 22e4 * kg,
                      rho = 1.2 * kg/m**3,
                      C_d = 0.3,
                      angle = 45 * deg,
                      velocity = 40 * m / s,
                      duration = 5.1 * s)

#not done with this cell

# %%
def distancedif (t):
    yachtv=8.74556
    x0=10
    
    boatdistance=x0+yachtv*(t)
    return boatdistance

# %%
distancedif(10)
# Out:
# 97.45559999999999

# %%
def targetmove(t):
    tseries=TimeSeries()
    for i in linrange(t):
        tseries[i+t]=distancedif(i)
    return tseries

# %%
x=targetmove(25)

# %%
newfig()
plot(x)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def energy(nump):
    massp=75     #in kg = 165lbs
    h=10 #meters
    E=massp*nump*(9.8)*h
    return E

# %%
energy(10)
# Out:
# 73500.00000000001

# %%
def E2v(nump):
    E=energy(nump)
    massp=75 #kg
    v=sqrt((2*E)/massp)
    return v

# %%
E2v(10)
# Out:
# 44.271887242357316

# %%
def hofagent(nump):
    v_init=E2v(nump)
    angle=45 #degrees

# %%
def Fonimpact(xtraveledbyagent,v0,vf):
    KEo=.5*(massp*nump)*v0**2
    KEf=.5*(massp*nump)*vf**2
    change=KEf-KEo
    F=change/xtraveledbyagent
    return F

# %%
def position(nump, t):
    v=v_init(nump)
    dvdt=accman1(nump)
    ypos= .5*dvdt*t**2 + v*t
    return ypos

# %%
def forceoflaunch(nump):    
    finalvel=14    #m/s
    Ke=.5*nump*(finalvel**2)
    F=Ke
    return F
forceoflaunch(5)
# Out:
# 490.0

# %%
def v_init(nump):
    m=75
    vout=14*m*nump/m  #14 is calculated above
    return vout

# %%
def accman1(nump):
    Vo=v_init(nump)
    m=75
    angle=45 #deg
    fd=1.14*Vo**2
    ax=fd*sin(angle)/m
    ay=9.8+((fd*cos(angle))/m)
    aa=(ax**2)+(ay**2)
    a=sqrt(aa)
    return a
accman1(3)
# Out:
# 33.03088207884754

# %%
system=System(t0=0, t_end=10)
def yposovertime(system):
    res=TimeSeries()
    for i in linrange(system.t0, system.t_end):
        res[i]=position(3, i)
        if i>0 and position(3,i)<=0:
            break
    system.yresults=res
    return system.yresults
yposovertime(system)
system.yresults
# Out:
# 0        0.000000
# 1       58.515441
# 2      150.061764
# 3      274.638969
# 4      432.247057
# 5      622.886026
# 6      846.555877
# 7     1103.256611
# 8     1392.988227
# 9     1715.750724
# 10    2071.544104
# dtype: float64

# %%
newfig()
plot(system.yresults, label="Vertical Height over Time")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
def xposition(x_v_init, acc, t):
    xpos=x_v_init*t+.5*acc*t**2
    return xpos

# %%
def xposovertime(system,t):
    res=TimeSeries()
    for i in linrange(system.t0, system.t_end):
        res[i]=xposition(2, i,t)
    system.results=res
    return system.results
#xposovertime(system,t)
#system.results

# %%
newfig()
#plot(system.results, system.yresults, label="trajectory of agent over time")
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
def ppl(v_init2, t, acc):
    """Calculates vertical position of jumpers over time
    initial position is 10 meters"""
    ypos=-acc*t**2+v_init2*t + 10
    return ypos

# %%
def pplovertime(system):
    res=TimeSeries()
    for i in linrange(system.t0, system.t_end):
        res[i]=ppl(0, i, 9.8)
    system.results=res
    return system.results
pplovertime(system)
system.results
# Out:
# 0      10.0
# 1       0.2
# 2     -29.2
# 3     -78.2
# 4    -146.8
# 5    -235.0
# 6    -342.8
# 7    -470.2
# 8    -617.2
# 9    -783.8
# 10   -970.0
# dtype: float64

# %%
m = UNITS.meter
s = UNITS.second
kg = UNITS.kilogram
degree = UNITS.degree
radian = UNITS.radian
condition = Condition(x = 0, 
                      y = 0,
                      g = 9.8,
                      mass = 75,
                      rho = 1.2,
                      C_d = 0.3,
                      angle = 45 * degree,
                      surfacearea=1.9)

#(x=m, y=m, g=m/s**2, mass=kg, rho=kg/m**3, c_d=dimensionless, angle=degrees, surfacearea=m**2)

# %%
def make_system(condition, nump):
    """Make a system object.
    
    condition: Condition object with angle, velocity, x, y,
               diameter, duration, g, mass, rho, and C_d
               
    returns: System object
    """
    unpack(condition)
    
    # convert angle to degrees
    theta = np.deg2rad(angle)
    
    # compute x and y components of velocity
    vx, vy = pol2cart(theta, v_init(nump))
    
    # make the initial state
    init = State(x=x, y=y, vx=vx, vy=vy)
    
    # compute area from diameter
    area = surfacearea
    
    # compute timestamps
    ts = linspace(0, 9, 100)
    
    return System(init=init, g=g, mass=mass, 
                  area=area, rho=rho, C_d=C_d, ts=ts)

# %%
system = make_system(condition, 3)
system
# Out:
# init    x                                    0
# y      ...
# g                                                     9.8
# mass                                                   75
# area                                                  1.9
# rho                                                   1.2
# C_d                                                   0.3
# ts      [0.0, 0.0909090909091, 0.181818181818, 0.27272...
# dtype: object

# %%
def slope_func(state, t, system):
    """Computes derivatives of the state variables.
    
    state: State (x, y, x velocity, y velocity)
    t: time
    system: System object with g, rho, C_d, area, mass
    
    returns: sequence (vx, vy, ax, ay)
    """
    x, y, vx, vy = state
    unpack(system)
    
    a_grav = Vector(0, -g)

    v = Vector(vx, vy) #* m/s
    
    f_drag = -rho * v.mag * v * C_d * area / 2
    a_drag = f_drag / mass
    
    a = a_grav + a_drag
    
    return vx, vy, a.x, a.y

# %%
x=slope_func(system.init, 0, system)
x
# Out:
# (<Quantity(29.698484809834998, 'dimensionless')>,
#  <Quantity(29.698484809834998, 'dimensionless')>,
#  <Quantity(-5.687853810779599, 'dimensionless')>,
#  <Quantity(-15.4878538107796, 'dimensionless')>)

# %%
run_odeint(system, slope_func)

# %%
xs=system.results.x
ys=system.results.y
newfig()
plot(xs, ys)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
v_init(100)
# Out:
# 1400.0

# %%
def flight_time(system):
    run_odeint(system, slope_func)
    y = system.results.y
    time_max_height = y.idxmax()
    idx_time_max_height = y.index.get_loc(time_max_height)
    inverse = Series(y.index[idx_time_max_height:], index=y.values[idx_time_max_height:])
    
    T = interpolate(inverse, kind='cubic')
    #plot(y.index[idx_time_max_height:], T(y.index[idx_time_max_height:]), 'g-')
#     plot(y.values, T(y.values), 'r-')
    #plot(T(y.values), y.values, 'r-')
#     plot(inverse, 'b*')
    T_jump = T(3)
    return T_jump

# %%
newfig()
flight_time(system)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# array(5.154088506937369)

# %%
system
# Out:
# init    x                                    0
# y      ...
# g                                                     9.8
# mass                                                   75
# area                                                  1.9
# rho                                                   1.2
# C_d                                                   0.3
# ts      [0.0, 0.0909090909091, 0.181818181818, 0.27272...
# dtype: object

# %%
newfig()
plot(ts,ys)
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
system
# Out:
# init    x                                    0
# y      ...
# g                                                     9.8
# mass                                                   75
# area                                                  1.9
# rho                                                   1.2
# C_d                                                   0.3
# ts      [0.0, 0.0909090909091, 0.181818181818, 0.27272...
# dtype: object

# %%
system.ts
# Out:
# array([ 0.        ,  0.09090909,  0.18181818,  0.27272727,  0.36363636,
#         0.45454545,  0.54545455,  0.63636364,  0.72727273,  0.81818182,
#         0.90909091,  1.        ,  1.09090909,  1.18181818,  1.27272727,
#         1.36363636,  1.45454545,  1.54545455,  1.63636364,  1.72727273,
#         1.81818182,  1.90909091,  2.        ,  2.09090909,  2.18181818,
#         2.27272727,  2.36363636,  2.45454545,  2.54545455,  2.63636364,
#         2.72727273,  2.81818182,  2.90909091,  3.        ,  3.09090909,
#         3.18181818,  3.27272727,  3.36363636,  3.45454545,  3.54545455,
#         3.63636364,  3.72727273,  3.81818182,  3.90909091,  4.        ,
#         4.09090909,  4.18181818,  4.27272727,  4.36363636,  4.45454545,
#         4.54545455,  4.63636364,  4.72727273,  4.81818182,  4.90909091,
#         5.        ,  5.09090909,  5.18181818,  5.27272727,  5.36363636,
#         5.45454545,  5.54545455,  5.63636364,  5.72727273,  5.81818182,
# ...

# %%
flight_time(system)
# Out:
# array(5.154088506937369)

# %%
run_odeint(system, slope_func)
y = system.results.y
idx = y.idxmax()
print(y.index)
print(idx)
# y.index.get_loc(idx)
y.index.get_loc(idx)
# Out:
# Float64Index([            0.0, 0.0909090909091,  0.181818181818,
#                0.272727272727,  0.363636363636,  0.454545454545,
#                0.545454545455,  0.636363636364,  0.727272727273,
#                0.818181818182,  0.909090909091,             1.0,
#                 1.09090909091,   1.18181818182,   1.27272727273,
#                 1.36363636364,   1.45454545455,   1.54545454545,
#                 1.63636363636,   1.72727272727,   1.81818181818,
#                 1.90909090909,             2.0,   2.09090909091,
#                 2.18181818182,   2.27272727273,   2.36363636364,
#                 2.45454545455,   2.54545454545,   2.63636363636,
#                 2.72727272727,   2.81818181818,   2.90909090909,
#                           3.0,   3.09090909091,   3.18181818182,
#                 3.27272727273,   3.36363636364,   3.45454545455,
#                 3.54545454545,   3.63636363636,   3.72727272727,
# ...

# %%
#sweep people
#make boat longer

# %%
def sweep_launchtime():
    res=TimeSeries()
    for i in linrange(1,16):
        system=make_system(condition, i)
        timetoreach3meters=flight_time(system)
        res[i]=timetoreach3meters
    return res

# %%
newfig()
sweep_launchtime()
plot(sweep_launchtime())
#x axis is number of people
#y axis is time in seconds for agent to reach 3 meters
#ASK NINJA FOR HELP WITH PRETTY THINGS ON GRAPH
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
def sweep_distance():
    """creates table of # of people versus the agent's horizontal distance traveled"""
    res=TimeSeries()
    for i in linrange(1, 16):
        system=make_system(condition, i)
        timetoreach3meters=flight_time(system)
        vel=slope_func(system.init, timetoreach3meters, system)
        res[i]=horiztravel(system)     
        print(res[i])
    return res

# %%
newfig()
sweep_distance()
plot(sweep_distance())

#COME BACK TO THIS
# Out:
# <img src="data:image/png;base64,..." width="575">
# 15.167605687273635
# 60.36880781765058
# 111.7031841978164
# 159.56894076767603
# 201.35096220623382
# 237.2644341378712
# 268.22652842670436
# 295.18154481095553
# 318.9930044130015
# 340.39787529525347
# 359.97245177498553
# 378.13484400557354
# 395.16072355024517
# 411.20274879736826
# 426.3109099166468
# 440.4546156078577
# 15.167605687273635
# 60.36880781765058
# 111.7031841978164
# 159.56894076767603
# 201.35096220623382
# 237.2644341378712
# 268.22652842670436
# 295.18154481095553
# 318.9930044130015
# 340.39787529525347
# 359.97245177498553
# 378.13484400557354
# 395.16072355024517
# 411.20274879736826
# 426.3109099166468
# 440.4546156078577

# %%
timetofall=1.429   #seconds

# %%
def delaytime():
    timetofall=1.429
    timetofly=sweep_launchtime()
    totalflytime = timetofall + timetofly
    return totalflytime

# %%
print(delaytime())
# Out:
# 1     3.02439
# 2     5.02294
# 3     6.58309
# 4     7.84885
# 5     8.88599
# 6     9.74872
# 7     10.4785
# 8     11.1071
# 9     11.6645
# 10    12.1805
# 11    12.6818
# 12    13.1908
# 13    13.7259
# 14    14.3012
# 15    14.9277
# 16    15.6132
# dtype: object

# %%
def horiztravel(system):
    run_odeint(system, slope_func)
    x = system.results.x
    timetoreach3meters=flight_time(system)
    
    #time_max_height = x.idxmax()
    #idx_time_max_height = y.index.get_loc(time_max_height)
    #inverse = Series(y.index[idx_time_max_height:], index=y.values[idx_time_max_height:])
    
    T = interpolate(x, kind='cubic')
    #plot(y.index[idx_time_max_height:], T(y.index[idx_time_max_height:]), 'g-')
#     plot(y.values, T(y.values), 'r-')
    #plot(T(y.values), y.values, 'r-')
#     plot(inverse, 'b*')
    T_jump = T(timetoreach3meters)
    return T_jump

# %%
horiztravel(system)
# Out:
# array(111.7031841978164)

# %%
def angletolaunch(system,t):
    launchangle=TimeSeries()
    adjacentlength=10 #meters
    for i in linrange(-t,t):
        distancetoboat=distancedif(i)
        launchangle[i+t]=np.rad2deg(acos(adjacentlength/distancetoboat))
        # convert angle to degrees
        #theta = np.deg2rad(angle)
    
    # compute x and y components of velocity
    #vx, vy = pol2cart(theta, v_init(nump))
    return launchangle

# %%
newfig()
plot(angletolaunch(system, 15))
# Out:
# <img src="data:image/png;base64,..." width="575">

# %%
def inverse(system, t, xdistance):
    x=targetmove(t)
    #print(x)
    time_min_height=x.idxmin()
    idx_time_min_height = x.index.get_loc(time_min_height)
    inverse = Series(x.index[idx_time_min_height:], index=x.values[idx_time_min_height:])
    T = interpolate(x, kind='cubic')    
    T_thing=T(xdistance)
    return T_thing

# %%
newfig()
def compare(t, nump):
    time=TimeSeries()
    for i in linrange(1,nump,1):
        system=make_system(condition, i)
        xdistance=horiztravel(system)
        print(xdistance)
        
        time[i]=inverse(system, t, xdistance)
        
        checktime=time[i]
        check=distancedif(checktime)
        print(check)
    return time
    
plot(compare(20,5))
# Out:
# <img src="data:image/png;base64,..." width="640">
# 15.167605687273635
# 493.46869754112646 dimensionless
# 60.36880781765058
# 2939.372094441026 dimensionless
# 111.7031841978164
# 6681.262660421332 dimensionless
# 159.56894076767603
# 9610.833329658646 dimensionless
# 201.35096220623382
# 11413.070150762373 dimensionless

# %%
 #endtime = t
    #results = correlation(system, endtime)
    #x = linspace(endtime, 2*endtime, 3*endtime+1)
    #y = results(x)
    #plot(y,x)
